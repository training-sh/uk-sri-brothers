# %%
import zipfile
import os

ZIP_PATH = "/Volumes/workspace/default/raw/iranian-web-access.log.zip"
EXTRACT_DIR = "/Volumes/workspace/default/raw/iranian-web-logs"

os.makedirs(EXTRACT_DIR, exist_ok=True)

with zipfile.ZipFile(ZIP_PATH, "r") as z:
    z.extractall(EXTRACT_DIR)

print(z.namelist())
# Out:
# ['access.log']
